# %% [markdown]
# Import Necessary modules

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Display Images

# %%
def display(img_set, img_title='',row = 1 , col = 1):
    n = len(img_set)
    plt.figure(figsize=(20,20))
    for i in range(n):
        plt.subplot(row,col,i+1)
        if img_title[i]!='':
            plt.title(img_title[i])
        if len(img_set[i].shape)==2:
            plt.imshow(img_set[i], cmap='gray')
        else:
            plt.imshow(img_set[i])
        plt.axis('off')
    plt.show()
    plt.close()

# %% [markdown]
# Now load the image

# %%
img = plt.imread("resources/tuilip.png")
print(img.shape)

gray_img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
print(gray_img.shape)

img_set = [img, gray_img]
img_title = ["RGB imgae", "Gray-Scale Image"]

display(img_set, img_title, row = 1, col = 2)
# Out:
# (722, 697, 4)
# (722, 697)
